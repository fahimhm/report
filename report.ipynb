# %%
import pandas as pd
data = pd.read_excel("datasets/report_generator.xlsx")

import win32com.client as win32
outlook = win32.Dispatch('outlook.application')

import os
from os.path import join

import time
start = time.time()

import re

# %%
for training in data['training'].unique():
    train_base = data[data['training'] == training]
    for date_start in train_base['waktu'].unique():
        date_base = train_base[train_base['waktu'] == date_start]
        table_1 = date_base[['training', 'trainer', 'waktu']].set_index('training')
        table_1 = table_1.transpose()
        table_2 = date_base[['peserta', 'dept', 'atasan', 'Post test', 'Kehadiran']]
        ts = pd.to_datetime(str(date_start))
        d = ts.strftime('%Y-%m-%d %H:%M')
        # --email
        mail = outlook.CreateItem(0)
        mail.Subject = "Report | " + training
        for recipient in date_base['email_optional'].unique():
            mail.Recipients.Add(recipient)
        for carbon in date_base['email_trainer'].unique():
            cc = mail.Recipients.Add(carbon)
            cc.Type = 2
        default = mail.Recipients.Add('prameswari.kristal@nutrifood.co.id')
        default.Type = 2
        total_id_1 = 'totalID1'
        header_id_1 = 'headerID1'
        total_id_2 = 'totalID2'
        header_id_2 = 'headerID2'
        style_1_in_html = """<style>table#{total_table} {{color='black';font-size:13px; text-align:left; border:0.2px solid black; border-collapse:collapse; table-layout:fixed; padding:10px; width=100%; height="250"; text-align:left}} thead#{header_table} {{background-color: #fff645; color:#000000}}</style>""".format(total_table=total_id_1, header_table=header_id_1)
        style_2_in_html = """<style>table#{total_table} {{color='black';font-size:13px; text-align:center; border:0.2px solid black; border-collapse:collapse; table-layout:fixed; padding:10px; width=100%; height="250"; text-align:center}} thead#{header_table} {{background-color: #fff645; color:#000000}}</style>""".format(total_table=total_id_2, header_table=header_id_2)
        table_1_in_html = table_1.to_html()
        table_1_in_html = re.sub(r'<table', r'<table id=%s ' % total_id_1, table_1_in_html)
        table_1_in_html = re.sub(r'<thead', r'<thead id=%s ' % header_id_1, table_1_in_html)
        table_2_in_html = table_2.to_html(index=False)
        table_2_in_html = re.sub(r'<table', r'<table id=%s ' % total_id_2, table_2_in_html)
        table_2_in_html = re.sub(r'<thead', r'<thead id=%s ' % header_id_2, table_2_in_html)
        body1 = "<p>Dear rekan-rekan leader,<br/>Berikut adalah report dari pelaksanaan training:<br/></p>"
        body2 = style_1_in_html + table_1_in_html
        body3 = style_2_in_html + table_2_in_html
        body4 = "<p>Terimakasih,<br/><br/>Generated by pyYDL any issue please inform prameswari.kristal@nutrifood.co.id<br/></p>"
        body5 = "<br/>"
        mail.HTMLBody = body1 + body2 + body5 + body3 + body4
        mail.Send()
        
        print("Report training " + training + "tanggal " + str(d) + " sudah terkirim.")
# Out:
# Report training POK Basic Critical Thinkingtanggal 2019-07-11T14:00:00.000000000 sudah terkirim.
# Report training Ketemu Suhadi - as Manager QCtanggal 2019-07-16T14:00:00.000000000 sudah terkirim.
# Report training POK Flow Processtanggal 2019-07-15T14:00:00.000000000 sudah terkirim.
# Report training POK Presentation Skill Praktektanggal 2019-07-18T14:00:00.000000000 sudah terkirim.
# Report training Sistem Jaminan Mututanggal 2019-07-29T14:00:00.000000000 sudah terkirim.
# Report training POK Workshop Komunikasi Efektiftanggal 2019-07-31T14:00:00.000000000 sudah terkirim.

# %%
end = time.time()
durasi = (end - start)
print("Total seluruh proses " + str(durasi) + " detik")
# input("Press enter to exit")
# Out:
# Total seluruh proses 0.24020099639892578 detik

# %%
import re
data_in_html = data.to_html(index=False)
total_id = 'totalID'
header_id = 'headerID'
style_in_html = """<style>table#{total_table} {{color='black';font-size:13px; text-align:center; border:0.2px solid black; border-collapse:collapse; table-layout:auto; width=100%; height="250"; text-align:center}} thead#{header_table} {{background-color: #fff645; color:#000000}}</style>""".format(total_table=total_id, header_table=header_id)
data_in_html = re.sub(r'<table', r'<table id=%s ' % total_id, data_in_html)
data_in_html = re.sub(r'<thead', r'<thead id=%s ' % header_id, data_in_html)

# %%
from IPython.display import HTML
HTML(style_in_html + data_in_html)
# Out:
# <style>table#totalID {color='black';font-size:13px; text-align:center; border:0.2px solid black; border-collapse:collapse; table-layout:auto; width=100%; height="250"; text-align:center} thead#headerID {background-color: #fff645; color:#000000}</style><table id=totalID  border="1" class="dataframe">
#   <thead id=headerID >
#     <tr style="text-align: right;">
#       <th>training</th>
#       <th>trainer</th>
#       <th>hari</th>
#       <th>waktu</th>
#       <th>peserta</th>
#       <th>dept</th>
#       <th>atasan</th>
#       <th>email_peserta</th>
#       <th>duration</th>
#       <th>meeting_room</th>
#       <th>email_meeting_room</th>
#       <th>email_trainer</th>
#       <th>email_optional</th>
#       <th>Undangan</th>
#       <th>Post test</th>
#       <th>Kehadiran</th>
#       <th>Kode Evaluasi training</th>
#       <th>Email</th>
#       <th>FDH</th>
#       <th>Info Email</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>POK Basic Critical Thinking</td>
#       <td>Kristal Prima</td>
#       <td>Jumat</td>
#       <td>2019-07-11 14:00:00</td>
#       <td>Prayoga Noer Tamtomo</td>
#       <td>GLF</td>
#       <td>Hestiana / Fajrina + Penyelia</td>
#       <td>Tamtomo.prayoga@nutrifood.co.id</td>
#       <td>120</td>
#       <td>Pletok</td>
#       <td>rpletok@nutrifood.co.id</td>
#       <td>prameswari.kristal@nutrifood.co.id</td>
#       <td>fahimhadimaula@gmail.com</td>
#       <td>done</td>
#       <td>100</td>
#       <td>Hadir</td>
#       <td>AB</td>
#       <td>done</td>
#       <td>done</td>
#       <td>done</td>
#     </tr>
#     <tr>
#       <td>Ketemu Suhadi - as Manager QC</td>
#       <td>Suhadi</td>
#       <td>Selasa</td>
#       <td>2019-07-16 14:00:00</td>
#       <td>Asep Khanuri</td>
#       <td>GRB</td>
#       <td>Galih N / David Rahmat / Penyelia</td>
#       <td>akkhanuri@gmail.com</td>
#       <td>120</td>
#       <td>Pletok</td>
#       <td>rpletok@nutrifood.co.id</td>
#       <td>prameswari.kristal@nutrifood.co.id</td>
#       <td>fahimhadimaula@gmail.com</td>
#       <td>done</td>
#       <td>90</td>
#       <td>Hadir</td>
#       <td>CD</td>
#       <td>done</td>
#       <td>done</td>
#       <td>done</td>
#     </tr>
#     <tr>
#       <td>POK Flow Process</td>
#       <td>Henny Susanty</td>
#       <td>senin</td>
#       <td>2019-07-15 14:00:00</td>
#       <td>Yogi Kusnadi</td>
#       <td>GRB</td>
#       <td>Galih N / David Rahmat / Penyelia</td>
#       <td>ykusnadi35@gmail.com</td>
#       <td>120</td>
#       <td>Pletok</td>
#       <td>rpletok@nutrifood.co.id</td>
#       <td>prameswari.kristal@nutrifood.co.id</td>
#       <td>fahimhadimaula@gmail.com</td>
#       <td>done</td>
#       <td>0</td>
#       <td>Tidak</td>
#       <td>EF</td>
#       <td>done</td>
#       <td>done</td>
#       <td>done</td>
#     </tr>
#     <tr>
#       <td>POK Presentation Skill Praktek</td>
#       <td>Kristal Prima</td>
#       <td>Kamis</td>
#       <td>2019-07-18 14:00:00</td>
#       <td>Asep Khanuri</td>
#       <td>GRB</td>
#       <td>Galih N / David Rahmat / Penyelia</td>
#       <td>akkhanuri@gmail.com</td>
#       <td>120</td>
#       <td>Pletok</td>
#       <td>rpletok@nutrifood.co.id</td>
#       <td>prameswari.kristal@nutrifood.co.id</td>
#       <td>fahimhadimaula@gmail.com</td>
#       <td>done</td>
#       <td>70</td>
#       <td>Hadir</td>
#       <td>GH</td>
#       <td>done</td>
#       <td>done</td>
#       <td>done</td>
#     </tr>
#     <tr>
#       <td>Sistem Jaminan Mutu</td>
#       <td>Iman Budiman</td>
#       <td>Senin</td>
#       <td>2019-07-29 14:00:00</td>
#       <td>Yogi Kusnadi</td>
#       <td>GRB</td>
#       <td>Galih N / David Rahmat / Penyelia</td>
#       <td>ykusnadi35@gmail.com</td>
#       <td>120</td>
#       <td>Angkringan</td>
#       <td>rangkringan@nutrifood.co.id</td>
#       <td>prameswari.kristal@nutrifood.co.id</td>
#       <td>fahimhadimaula@gmail.com</td>
#       <td>done</td>
#       <td>0</td>
#       <td>Tidak</td>
#       <td>IJ</td>
#       <td>done</td>
#       <td>done</td>
#       <td>done</td>
#     </tr>
#     <tr>
#       <td>POK Workshop Komunikasi Efektif</td>
#       <td>Kristal Prima</td>
#       <td>Rabu</td>
#       <td>2019-07-31 14:00:00</td>
#       <td>Erda Octadayani</td>
#       <td>GRA</td>
#       <td>Rizal Bahara / Eko + Penyelia/Admin</td>
#       <td>octadayani.erda@nutrifood.co.id</td>
#       <td>120</td>
#       <td>Angkringan</td>
#       <td>rangkringan@nutrifood.co.id</td>
#       <td>prameswari.kristal@nutrifood.co.id</td>
#       <td>fahimhadimaula@gmail.com</td>
#       <td>done</td>
#       <td>50</td>
#       <td>Hadir</td>
#       <td>KL</td>
#       <td>done</td>
#       <td>done</td>
#       <td>done</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(data.to_html().replace('<table ','<table id="table1" '))
# Out:
# <table id="table1" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>training</th>
#       <th>trainer</th>
#       <th>hari</th>
#       <th>waktu</th>
#       <th>peserta</th>
#       <th>dept</th>
#       <th>atasan</th>
#       <th>email_peserta</th>
#       <th>duration</th>
#       <th>meeting_room</th>
#       <th>email_meeting_room</th>
#       <th>email_trainer</th>
#       <th>email_optional</th>
#       <th>Undangan</th>
#       <th>Post test</th>
#       <th>Kehadiran</th>
#       <th>Kode Evaluasi training</th>
#       <th>Email</th>
#       <th>FDH</th>
#       <th>Info Email</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>POK Basic Critical Thinking</td>
#       <td>Kristal Prima</td>
#       <td>Jumat</td>
#       <td>2019-07-11 14:00:00</td>
#       <td>Prayoga Noer Tamtomo</td>
#       <td>GLF</td>
#       <td>Hestiana / Fajrina + Penyelia</td>
#       <td>Tamtomo.prayoga@nutrifood.co.id</td>
#       <td>120</td>
#       <td>Pletok</td>
#       <td>rpletok@nutrifood.co.id</td>
#       <td>prameswari.kristal@nutrifood.co.id</td>
#       <td>fahimhadimaula@gmail.com</td>
#       <td>done</td>
#       <td>100</td>
#       <td>Hadir</td>
#       <td>AB</td>
#       <td>done</td>
#       <td>done</td>
#       <td>done</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>